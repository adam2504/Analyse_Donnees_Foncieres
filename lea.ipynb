# %%
# Cellule 1 : Import
from rentabilite_functions import analyse_complete_rentabilite

# Cellule 2 : Exécution
resultats = analyse_complete_rentabilite()
# Out:
# ...
# ANALYSE COMPLÈTE DE RENTABILITÉ LOCATIVE
# Appartements étudiants ≤ 45m²
# ...
#
#
# ...
# ÉTAPE 1 : EXTRACTION ET ANALYSE DES PRIX D'ACHAT (DVF 2024)
# ...
#
# Données extraites : 21,269 transactions après nettoyage
# Lignes supprimées (aberrantes) : 826
#
# ...
# CLASSEMENT DES VILLES PAR PRIX MOYEN AU M²
# ...
#  Rang     Commune  Nombre de ventes  Prix moyen €/m²  Prix min €/m²  Prix max €/m²
#     1      ANGERS               870          12331.0         1200.0        87500.0
#     2       LILLE              1591           9791.0         1071.0        93103.0
#     3       REIMS               843           8206.0         1119.0        90909.0
#     4       ROUEN              1097           8188.0         1000.0        92333.0
#     5       NANCY               830           7945.0         1000.0        81579.0
#     6      ANNECY               394           7710.0         1846.0        60917.0
#     7    BORDEAUX              1529           7377.0         1016.0        72105.0
# ...

# %% [markdown]
# # Partie Logement vacant

# %%
from analyse_logements_vacants import analyse_logements_vacants

if __name__ == "__main__":
    analyse_logements_vacants()
# Out:
# c:\Users\rivat\OneDrive\Documents\GitHub\Analyse_Donnees_Foncieres\analyse_logements_vacants.py:17: DtypeWarning: Columns (1,12,14,16,23,24) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_communes = pd.read_csv(f"{BDD}/communes-france-2025.csv", sep=",")
# c:\Users\rivat\OneDrive\Documents\GitHub\Analyse_Donnees_Foncieres\analyse_logements_vacants.py:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_communes_coords["code_insee"] = df_communes_coords["code_insee"].astype(str)
# ✅ Analyse des logements vacants terminée !

# %% [markdown]
# # Partie rentabilité par quartiers : Rennes

# %%
from rentabilité_quartiers_rennes import analyse_rentabilite_quartiers_rennes

if __name__ == "__main__":
    analyse_rentabilite_quartiers_rennes()
# Out:
# Analyse de rentabilité des quartiers de Rennes terminée !
