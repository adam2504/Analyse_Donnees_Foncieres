# %% [markdown]
# ## Persona : Léa, une jeune investisseuse étudiante
#
# **Profil :**
# - 24 ans, diplômée de l'EM Lyon
# - Première expérience professionnelle après 2 ans d'alternance
# - Aide parentale pour le financement + épargne personnelle (~15 000 €)
# - Objectif : réaliser un **premier investissement locatif** dans une **ville étudiante dynamique**
#
# ---
#
# ### Objectif d'investissement
# > Trouver le **meilleur investissement locatif étudiant** possible avec un **budget global de 200 000 €**,
# > en analysant la rentabilité brute dans les **principales villes étudiantes françaises** (studios et T1 ≤45m²)
#
# ---
#
# ###  Hypothèses financières
# | Élément | Montant estimé |
# |----------|----------------|
# | Prix d'achat visé | 160 000 – 180 000 € |
# | Apport personnel | 15 000 € |
# | Prêt immobilier estimé | 180 000 € sur 20 ans |
# | Budget total (frais inclus) | **≈ 200 000 €** |
# | Objectif de rentabilité brute | **≥ 2,5 %** |
#
# ---
#
# ###  Besoins data de Léa
# - Analyser l'**évolution du prix au m² à l'achat et des loyers étudiants** en France
# - Etudier **la rentabilité brute en France** en 2024
# - Visualiser les **villes à forte concentration étudiante** en France
# - Évaluer le **taux de vacance locative** en France pour anticiper les périodes creuses (notamment l'été où les étudiants quittent les logements)
# - Identifier la ville la plus adaptée à un **faible risque de vacance** en privilégiant la **rentabilité rapide**
# - Comparer **les quartiers les plus rentables (rentabilité brute)** à Rennes
# - Analyser la **localisation/nombre des transports en commun** pour identifier les zones les plus attractives pour les étudiants à Rennes
# - Analyser la **localisation des universités/grandes écoles** à Rennes et **la densité étudiante par quartiers** à Rennes
# - Analyser les **quartiers vivants (nombre de resto, bars, et supermarchés)** à Rennes
# - Fournir une **recommandation finale : "où investir avec 200k€ ?"**

# %%
import sys
from pathlib import Path

# Ajouter le dossier projet (parent de notebooks et src) au sys.path
project_path = Path.cwd().parent
sys.path.append(str(project_path))

# %% [markdown]
# ## Partie 1 : Vue générale sur la France ##

# %% [markdown]
# ### Besoin n°1 et n°2: Analyser l'**évolution du prix au m² à l'achat et des loyers étudiants** en France et Etudier **la rentabilité brute en France** en 2024 ###

# %%
# Import
from src.axel_valentine_rentabilite_functions import analyse_complete_rentabilite

# Exécution
resultats = analyse_complete_rentabilite()
# Out:
# ================================================================================
# ANALYSE COMPLÈTE DE RENTABILITÉ LOCATIVE
# Appartements étudiants ≤ 45m²
# ================================================================================
#
#
# ================================================================================
# ÉTAPE 1 : EXTRACTION ET ANALYSE DES PRIX D'ACHAT (DVF 2024)
# ================================================================================
#
# Données extraites : 21,269 transactions après nettoyage
# Lignes supprimées (aberrantes) : 826
#
# ================================================================================
# CLASSEMENT DES VILLES PAR PRIX MOYEN AU M²
# ================================================================================
#  Rang     Commune  Nombre de ventes  Prix moyen €/m²  Prix min €/m²  Prix max €/m²
#     1      ANGERS               870          12331.0         1200.0        87500.0
#     2       LILLE              1591           9791.0         1071.0        93103.0
#     3       REIMS               843           8206.0         1119.0        90909.0
#     4       ROUEN              1097           8188.0         1000.0        92333.0
#     5       NANCY               830           7945.0         1000.0        81579.0
#     6      ANNECY               394           7710.0         1846.0        60917.0
#     7    BORDEAUX              1529           7377.0         1016.0        72105.0
#     8    TOULOUSE              2511           6911.0         1000.0       100000.0
#     9       TOURS               835           6730.0         1200.0        89286.0
#    10        NICE              2764           6705.0         1000.0        96048.0
#    11      NANTES              1580           6477.0         1021.0        98562.0
#    12     AJACCIO               154           6322.0         1481.0        68750.0
#    13 MONTPELLIER              1661           5630.0         1038.0        90731.0
#    14      RENNES              1024           5609.0         1000.0        62222.0
#    15      TOULON               937           5569.0         1000.0        61167.0
#    16        CAEN               734           5291.0         1154.0        55263.0
#    17    GRENOBLE               856           5247.0         1111.0        89250.0
#    18       DIJON              1059           4776.0         1000.0        71000.0
#
#
# Prix moyen national : 7,033 €/m²
# Ville la plus chère : ANGERS (12,331 €/m²)
# Ville la moins chère : DIJON (4,776 €/m²)
# ================================================================================
# ÉTAPE 2 : EXTRACTION ET ANALYSE DES LOYERS
# ================================================================================
#
# ================================================================================
# LOYERS MOYENS PAR VILLE
# ================================================================================
#            Ville  Loyer_moyen_m2  Nombre_observations
#          AJACCIO           17.16                 5778
#           ANNECY           16.34                20798
#         BORDEAUX           14.18               137865
# CLERMONT-FERRAND           11.31               117627
#             LYON           16.25               132434
#        MARSEILLE           15.41               360921
#      MONTPELLIER           15.48               151721
#            PARIS           27.76                12363
#            PARIS           19.98                31000
#           RENNES           13.92               208055
#       STRASBOURG           15.06                47720
#           TOULON           14.56               171431
#         TOULOUSE           13.57               353939
#
#
# Loyer moyen national : 16.23 €/m²
# Ville la moins chère : CLERMONT-FERRAND (11.31 €/m²)
# Ville la plus chère : PARIS (27.76 €/m²)
# ================================================================================
# ÉTAPE 3 : CALCUL DE LA RENTABILITÉ LOCATIVE
# ================================================================================
#
# ========================================================================================================================
# CLASSEMENT DES VILLES PAR RENTABILITÉ BRUTE
# ========================================================================================================================
#  Rang     Commune  Rentabilite_brute_%  Loyer_moyen_m2  Loyer_annuel_m2  Prix_achat_moyen_m2  Nombre_ventes
#     1 MONTPELLIER                 3.30           15.48           185.76              5629.62           1661
#     2     AJACCIO                 3.26           17.16           205.92              6322.45            154
#     3      TOULON                 3.14           14.56           174.72              5569.40            937
#     4      RENNES                 2.98           13.92           167.04              5608.53           1024
#     5      ANNECY                 2.54           16.34           196.08              7710.38            394
#     6    TOULOUSE                 2.36           13.57           162.84              6911.28           2511
#     7    BORDEAUX                 2.31           14.18           170.16              7376.94           1529
#
#
# Rentabilité moyenne : 2.84%
# Ville la plus rentable : MONTPELLIER (3.30%)
# Ville la moins rentable : BORDEAUX (2.31%)

# %% [markdown]
# ### Besoin n°3: Visualiser les **villes à forte concentration étudiante** en France  ###

# %%
from src.adam_analyse_etudiante import analyse_densite_etudiante

# Lancer l’analyse complète
df_resultat = analyse_densite_etudiante()
# Out:
# 📥 Chargement des données de population communale...
# ✅ 41 villes avec plus de 100k habitants chargées.
# 📥 Chargement des données d'enseignement supérieur...
# ✅ Données d’enseignement supérieur nettoyées et agrégées.
# 🔗 Fusion des données population ↔ étudiants...
# ✅ Fusion réalisée (41 correspondances trouvées).
# 🌍 Ajout des coordonnées géographiques via API Geocode (peut prendre du temps)...
# ✅ Coordonnées ajoutées.
# 📊 Génération des graphiques...
# ✅ Graphiques générés.
# 🗺️ Génération de la carte interactive...
# ✅ Carte interactive prête.
# 🎯 Analyse terminée avec succès.

# %% [markdown]
# ### Besoin n°4: Évaluer le **taux de vacance locative** en France pour anticiper les périodes creuses (notamment l'été où les étudiants quittent les logements)  ###

# %%
from src.lucien_analyse_logements_vacants import analyse_logements_vacants

if __name__ == "__main__":
    analyse_logements_vacants()
# Out:
# === ANALYSE DES LOGEMENTS VACANTS EN FRANCE ===
# En moyenne, les grandes communes françaises ont un taux de vacance d’environ 9.00%.
# La commune avec le **plus faible taux** de logements vacants est Toulon, avec seulement 3.40% de vacance.
# Ces villes sont généralement très dynamiques et recherchées : investir dans ces zones limite les risques de vacance locative.
# À l’inverse, les points les plus rouges sur la carte indiquent des villes où l’offre dépasse la demande, ce qui peut freiner la rentabilité à court terme.

# %% [markdown]
# ### Besoin n°5: Analyser la **dynamique du marché immobilier local : croissance ou baisse des prix et loyers sur les 5 dernières années** (entre Rennes et Bordeaux)  ###

# %%
from src.axel_loyer_bordeaux_rennes import analyse_loyer_bordeaux_rennes

analyse_loyer_bordeaux_rennes()
# Out:
# ======================  CONTEXTE DU CHOIX  ====================== :
#
# Après analyse des grandes villes françaises, deux se distinguent pour Léa : Rennes et Bordeaux.
# Nous allons comparer leur évolution des loyers pour déterminer laquelle répond le mieux à son besoins.
# A savoir une rentabilité rapide, une stabilité du marché et un faible risque de vacance.
# ======================  ANALYSE ET INTERPRÉTATION  ====================== :
#
# Entre 2020 et 2024, les loyers ont augmenté d’environ 9 % à Bordeaux et Rennes.
# En 2024 : 16,3 €/m² à Bordeaux contre 15,9 €/m² à Rennes.
# Deux courbes similaires : progression régulière, marché tendu dans les deux villes.
#
# Bordeaux : loyers plus élevés, coût d’achat plus important, marché plus concurrentiel.
# Rennes : marché plus accessible, stable, forte demande étudiante, risque moindre de vacance.
#
# De plus, comme vu précédemment, la rentabilité moyenne légèrement supérieure à Rennes (2,98 % contre 2,31 %).
#
# Conclusion : Rennes combine loyers modérés, stabilité et rendement correct —
# un choix plus sûr et cohérent pour Léa.

# %% [markdown]
# ## Partie 2 : Vue resserrée sur des villes choisies (Rennes) ##

# %% [markdown]
# ### Besoin n°6: Comparer **les quartiers les plus rentables (rentabilité brute)** à Rennes  ###

# %%
from src.lucien_rentabilité_quartiers_rennes import analyse_rentabilite_quartiers_rennes

if __name__ == "__main__":
    analyse_rentabilite_quartiers_rennes()
# Out:
# === ANALYSE DE LA RENTABILITÉ DES QUARTIERS À RENNES ===
# À Rennes, la rentabilité moyenne des appartements est d’environ 2.94%.
# Les quartiers les plus rentables sont : Nord Saint Martin, Maurepas-Patton, Centre.
# Les quartiers les moins rentables sont : Lorient-Saint Brieuc, Atalante Beaulieu, Thabor-Saint Helier.
# Les logements autour de 30m² sont souvent plus rentables (petits T1/T2 étudiants).
# Les surfaces de 45m² sont plus stables à long terme, avec une vacance locative moindre.

# %% [markdown]
# ### Besoin n°7: Analyser la **localisation des universités/grandes écoles** à Rennes et **la densité étudiante par quartiers** à Rennes ###

# %%
# Import de la fonction principale depuis module
from src.adam_analyse_concentration_etudiante_carte_rennes import analyse_concentration_rennes

# Exécution complète de l’analyse
fig, iris_plot, df_rennes = analyse_concentration_rennes()

# Affichage de la carte interactive
fig.show()
# Out:
# 🚀 DÉBUT DE L’ANALYSE : concentration étudiante à Rennes
#
# [1/6] 📦 Chargement des données d’enseignement supérieur...
# ✅ Données chargées : 105,660 lignes, 27 colonnes
#
# [2/6] 🧹 Filtrage des données pour Rennes...
# Nombre d'établissements à Rennes avant nettoyage : 1,531
# → Après nettoyage : 1,461 établissements avec coordonnées valides
# ✅ Conversion en GeoDataFrame réussie.
#
# [3/6] 🗺️ Chargement des contours IRIS et références...
# → Téléchargement du fichier IRIS...
# ✅ Fichier téléchargé et enregistré localement.
# ✅ 146 IRIS trouvés pour la commune de Rennes.
#
# [4/6] 📊 Calcul des statistiques par IRIS...
# → Établissements rattachés à un IRIS : 1,458
# ✅ Statistiques calculées avec succès.
#
# [5/6] 🗺️ Génération de la carte interactive...
# ✅ Carte générée avec succès.
#
# ✅ ANALYSE TERMINÉE AVEC SUCCÈS ✅

# %%
from src.adam_analyse_concentration_etudiante_top10_rennes import afficher_widgets

# Lancement direct du tableau de bord interactif
afficher_widgets()
# Out:
# 🔄 Chargement et préparation des données de concentration étudiante à Rennes...
# 🚀 DÉBUT DE L’ANALYSE : concentration étudiante à Rennes
#
# [1/6] 📦 Chargement des données d’enseignement supérieur...
# ✅ Données chargées : 105,660 lignes, 27 colonnes
#
# [2/6] 🧹 Filtrage des données pour Rennes...
# Nombre d'établissements à Rennes avant nettoyage : 1,531
# → Après nettoyage : 1,461 établissements avec coordonnées valides
# ✅ Conversion en GeoDataFrame réussie.
#
# [3/6] 🗺️ Chargement des contours IRIS et références...
# → Téléchargement du fichier IRIS...
# ✅ Fichier téléchargé et enregistré localement.
# ✅ 146 IRIS trouvés pour la commune de Rennes.
#
# [4/6] 📊 Calcul des statistiques par IRIS...
# → Établissements rattachés à un IRIS : 1,458
# ✅ Statistiques calculées avec succès.
#
# [5/6] 🗺️ Génération de la carte interactive...
# ✅ Carte générée avec succès.
#
# ✅ ANALYSE TERMINÉE AVEC SUCCÈS ✅
# ✅ Données prêtes pour l'affichage interactif.
# 🧩 Création des widgets interactifs...
# ✅ Widgets prêts à l’utilisation !
# interactive(children=(ToggleButtons(button_style='info', description='Afficher :', options=('Densité', "Nombre…

# %% [markdown]
# ### Besoin n°8 : Analyser la **localisation/nombre des transports en commun** pour identifier les zones les plus attractives pour les étudiants à Rennes  ###

# %%
from src.adam_analyse_concentration_transports_rennes import analyse_transports_rennes

fig1, fig2, stats_iris = analyse_transports_rennes()
# Out:
# ================================================================================
# ANALYSE DES IRIS - TRANSPORTS EN COMMUN A RENNES
# ================================================================================
#
# ETAPE 1 : Chargement des données IRIS
# --------------------------------------------------------------------------------
# OK - 48512 IRIS géographiques téléchargés
# OK - 146 IRIS conservés pour Rennes
# OK - Fusion terminée : 146 IRIS avec noms et géométries
#
# ================================================================================
# ETAPE 2 : Récupération des arrêts de transports depuis OpenStreetMap
# --------------------------------------------------------------------------------
# Envoi de la requête à l’API Overpass (peut durer 30-60s)...
# OK - 1368 arrêts récupérés
#
# ================================================================================
# ETAPE 3 : Catégorisation des arrêts
# --------------------------------------------------------------------------------
#
# Répartition par catégorie :
# categorie
# Bus      1279
# Métro      67
# Train      22
#
# ================================================================================
# ETAPE 4 : Jointure spatiale (transports x IRIS)
# --------------------------------------------------------------------------------
# OK - 1365 arrêts associés à un IRIS
#
# ================================================================================
# ETAPE 5 : Agrégation et calculs
# --------------------------------------------------------------------------------
#
# Top 10 IRIS les plus denses en transports en commun :
#                     LIB_IRIS  total_arrets  densite_arrets
# 29              Saint-Hélier            55           242.3
# 15  Parcheminerie Toussaints            43           217.2
# 13                 Parlement            18           152.5
# 80             Dalle Kennedy             9           149.3
# 9                 Cathédrale            28           124.7
# 85             Torigné Ouest            17           100.9
# 40          Emmanuel Mounier            16            97.4
# 42             Le Gast Ouest            19            91.0
# 76         Villejean Sud-Est            12            81.5
# 19        Dalle du Colombier             4            81.1
#
# ================================================================================
# ETAPE 6 : Génération des graphiques
# --------------------------------------------------------------------------------
# OK - Graphiques générés

# %% [markdown]
# ### Besoin n°9 : Analyser les **quartiers vivants (nombre de resto, bars, et supermarchés)** à Rennes ###

# %%
from src.valentine_analyse_quartiers_vivants import analyse_commerces_rennes

fig1, fig2, stats_iris = analyse_commerces_rennes()
# Out:
# ================================================================================
# ANALYSE DES IRIS - COMMERCES VIVANTS A RENNES
# ================================================================================
#
# ETAPE 1 : Chargement des donnees IRIS
# --------------------------------------------------------------------------------
# OK - 48512 IRIS géographiques téléchargés
# OK - 49444 IRIS chargés dans la base nationale
# OK - 146 IRIS conservés pour Rennes
# OK - Fusion terminée : 146 IRIS avec noms et géométries
#
# ETAPE 2 : Recuperation des commerces depuis OpenStreetMap
# --------------------------------------------------------------------------------
# OK - 942 commerces récupérés
#
# ETAPE 3 : Conversion et catégorisation
# OK - 942 commerces géolocalisés
# Répartition par catégorie :
#  categorie
# Restaurant     537
# Bar/Café       274
# Supermarché    131
# Name: count, dtype: int64
#
# ETAPE 4 : Jointure spatiale (commerces x IRIS)
# OK - 942 commerces associés à un IRIS
# OK - Graphiques générés

# %% [markdown]
# ### Besoin n°10 : Fournir une **recommandation finale : "où investir avec 200k€ ?"** ###

# %%
from src.analyse_finale_iris_rennes import pipeline_3d

# Lancer tout le pipeline et obtenir le merged GeoDataFrame
merged_146 = pipeline_3d()
